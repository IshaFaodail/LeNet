# %% [markdown]
# ## PROBLEM-2

# %% [markdown]
# ### Importing Dependecies

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
from scipy import linalg
# Out:
# WARNING:tensorflow:From C:\Users\Hp\AppData\Roaming\Python\Python311\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# ###  1) Question

# %% [markdown]
# #### 1.a- Downloading dataset

# %%
#load the mnist dataset
mnist = tf.keras.datasets.mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

# Add a channels dimension
x_train = x_train[..., tf.newaxis].astype("float32")
x_test = x_test[..., tf.newaxis].astype("float32")

# %%
x_train.shape
# Out:
# (60000, 28, 28, 1)

# %% [markdown]
# #### 1.b- Shape of a image

# %%
x_train[0].shape       #(28, 28, 1)
# Out:
# (28, 28, 1)

# %% [markdown]
# #### 1.c-Data in range from (1, 10)

# %%
x_traindata = x_train[0]     #visualising image
plt.imshow(x_traindata)

# %% [markdown]
# ### 2) Question

# %%
x = np.zeros((10000, 28, 28, 1))       #array of zeroes
for i in range (10000):
    index = np.random.randint(1, 60000)    #random index for the X
    x[i] = (x_train[index])#randomly getting 10000 images in x
#     print(index)
x = np.asarray(x)
x = x.reshape(10000, -1)               #flattening the images
x.shape #size of x (10000, 784)
# Out:
# (10000, 784)

# %%
img_initial = x[0].reshape(28,28)
plt.imshow(img_initial)

# %% [markdown]
# ### 3) Question

# %%
def standardise(X):
    mean = np.sum(X, axis = 0)/X.shape[0] #mean by sum along pixels(features) and divide by no. of pixels(features)
    Z = (X-mean)#standardise x by x - mean 
    print(mean.shape)
    return Z, mean

# %% [markdown]
# ### 4) Question

# %% [markdown]
# #### 4.a- standardise X

# %%
z, mean = standardise(x)        #shape(10000, 784)
z.shape
# Out:
# (784,)
# (10000, 784)

# %% [markdown]
# #### 4.b- Projection matrix

# %%
Rz = np.dot(z.T, z)/z.shape[0]     #correlation matrix
e, ev = linalg.eigh(Rz)    #eigen value and eigen vector calculation

# %%
ev.shape     ## eigen vector per column
# Out:
# (784, 784)

# %%
e_index = np.argsort(e)[::-1]      #sorting eigen values and eigen vectors in descending order
e_sorted = e[e_index]
ev_sorted = ev[:, e_index]    # we are sorting column vectors

# %%
p = np.dot(z, ev_sorted)       #projection matrix
p.shape
# Out:
# (10000, 784)

# %%
ev_sorted.shape
# Out:
# (784, 784)

# %% [markdown]
# ### 5) Question

# %% [markdown]
# #### 5.a- Varying P to get reconstructed image

# %%
result_x = []               # will store reconstructed x    
for i in range(24, 785, 20):
    ev_tilted = ev_sorted[:, :i]     #truncating eigen vector from 24, 44, .... in loop
    p_cap = np.dot(z, ev_tilted)     #projected matrix for truncated ev
    xnew_cap = np.dot(p_cap, ev_tilted.T)   #reconstructed images
    xx_cap = xnew_cap + mean         #adding mean corrosponding to it
    result_x.append(xx_cap)          #appending images to array

# %%
result_xx = np.asarray(result_x)

# %%
result_xx.shape    #shape of array containing all reconstructed images
# Out:
# (39, 10000, 784)

# %% [markdown]
# #### 5.b- Visualising the first image in each p and error calculation

# %%
l2_norm = []
fig = plt.figure(figsize= (50, 150))
for i in range (0,39):
    ax = fig.add_subplot(15, 3, i+1)
    im_final = result_xx[i][0].reshape(28, 28)
#     l2_norm.append(np.sqrt(np.sum(np.power((img_initial-im_final),2))))
    diff = np.sum(np.power(img_initial-im_final, 2))
    l2_norm.append(np.sqrt(diff))
    ax.imshow(im_final, cmap='gray')
    ax.set_title("p:"+str(20*i+24), fontsize='40')

# %% [markdown]
# #### 5.c- error using L2 norm

# %%
l2_norm   # l2 norm error
# Out:
# [4.016397189390433,
#  3.0891923574195133,
#  2.4180010676634796,
#  1.9784235671293728,
#  1.7638643545916106,
#  1.646593858743493,
#  1.3755991632288964,
#  1.2837876924410236,
#  1.1392824535912374,
#  1.0653927318681582,
#  0.9817385945351983,
#  0.887766347040775,
#  0.8152863522725571,
#  0.7391605535339164,
#  0.6778867510225254,
#  0.6337534025409961,
#  0.5139415084783633,
#  0.45538441507715804,
#  0.3785357362266542,
#  0.3195367278969669,
#  0.27428167443714213,
#  0.22097762805279705,
#  0.16809394945756959,
#  0.12754409712539871,
#  0.10000112494677148,
#  0.05470631327018085,
#  0.03140011709648517,
#  0.022612817147741347,
#  0.013567201460917671,
#  0.009580831810389313,
#  0.004165707327361442,
#  0.0005208456204620771,
#  1.0652393047765987e-12,
#  8.702168222355481e-13,
#  8.697732161016388e-13,
#  8.697731500905556e-13,
#  8.692075287454383e-13,
#  8.578671854209636e-13,
#  9.15978025955514e-14]

# %% [markdown]
# ### 6) Question

# %%
#plotting reconstructed error v/s p 
p_component = np.linspace(24, 784, 39)

# %%
plt.plot(p_component, l2_norm, '-*')
plt.title("Reconstruction error vs number of principal components graph")
plt.xlabel("Number of principal component")
plt.ylabel("Reconstructed error")
# Out:
# Text(0, 0.5, 'Reconstructed error')

# %%
xy = [[-2.5, 2.5, 1.5, -1.5, -0.5, 0.5 ], [-1, 1, 1, -1, 0, 0], [-0.5, 0.5, 0.5, -0.5, -0.5, 0.5]]
xy = np.asarray(xy)

# %%
Rx = np.dot(xy, xy.T)

# %%
p = Rx/6
p
# Out:
# array([[2.91666667, 1.33333333, 0.75      ],
#        [1.33333333, 0.66666667, 0.33333333],
#        [0.75      , 0.33333333, 0.25      ]])

# %%
e, l  = linalg.eigh(p)

# %%
e
# Out:
# array([0.03763144, 0.06597021, 3.72973169])

# %%
l
# Out:
# array([[ 0.46348339,  0.07377264,  0.8830293 ],
#        [-0.68375541, -0.60407458,  0.40935613],
#        [-0.56361483,  0.79350583,  0.22953609]])

# %%
Y = np.dot(l.T, xy)

# %%
Y
# Out:
# array([[-0.19314565,  0.19314565, -0.27033774,  0.27033774,  0.05006572,
#         -0.05006572],
#        [ 0.02289007, -0.02289007, -0.09666271,  0.09666271, -0.43363923,
#          0.43363923],
#        [-2.73169742,  2.73169742,  1.84866812, -1.84866812, -0.5562827 ,
#          0.5562827 ]])

# %%
ll = [[ 0.46348339,  0.07377264 ],
       [-0.68375541, -0.60407458],  [-0.56361483,  0.79350583]]
ll = np.asarray(ll)

# %%
yy = np.dot(ll.T, xy)

# %%
yy
# Out:
# array([[-0.19314565,  0.19314565, -0.27033774,  0.27033774,  0.05006572,
#         -0.05006572],
#        [ 0.02289007, -0.02289007, -0.09666271,  0.09666271, -0.43363924,
#          0.43363924]])

# %%
xy
np.asarray(xy)
# Out:
# array([[-2.5,  2.5,  1.5, -1.5, -0.5,  0.5],
#        [-1. ,  1. ,  1. , -1. ,  0. ,  0. ],
#        [-0.5,  0.5,  0.5, -0.5, -0.5,  0.5]])

# %%
Rx
# Out:
# array([[17.5,  8. ,  4.5],
#        [ 8. ,  4. ,  2. ],
#        [ 4.5,  2. ,  1.5]])

# %%
es, ls  = linalg.eigh(Rx)
